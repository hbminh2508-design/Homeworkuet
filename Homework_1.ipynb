# %% [markdown]
# <a href="https://colab.research.google.com/github/hbminh2508-design/Homeworkuet/blob/main/Homework_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Bài 1: Nhập vào số nguyên n, in ra màn hình số gấp đôi của n

# %%
n = int(input("Nhập số nguyên dương n: "))
print(n*2)
# Out:
# Nhập số nguyên dương n: 12
# 24

# %% [markdown]
# Bài 2: Một khu đất hình chữ nhật có chiều rộng a, chiều dài b. Người ra xây một khu
# vui chơi hình tròn tại vị trí trung tâm khu đất như hình vẽ. Nhập vào a, b. Hãy tính phần
# diện tích còn để trồng cây xung quanh là bao nhiêu. Biết pi = 3.14, lấy kết quả đến 2
# chữ số phần thập phân.
#
# ![bai2.png](data:image/png;base64,...)

# %%
a, b = map(float, input().split())
Shcn = a*b
Stron = 3.14*a
Strongcay = Shcn - Stron
print(f"{Strongcay:.2f}")
# Out:
# 2 4
# 1.72

# %% [markdown]
# Bài 3: Viết chương trình nhập vào một “kí tự” c, nếu nó là chữ hoa thì in ra chữ thường tương ứng và ngược lại nếu nó là chữ thường thì in ra chữ hoa tương ứng của nó. (xem trước cấu trúc lựa chọn: if….else, ma)

# %%
c = str(input())
if c.isupper():
  chu = c.lower()
elif c.islower():
  chu = c.upper()
print(chu)
# Out:
# E
# e

# %% [markdown]
# Bài 4: Viết chương trình nhập vào một “kí tự”, Kiểm tra xem c có phải là kí tự chữ cái
# không (hoa hoặc thường). Nếu đúng thì in ra “{c} là kí tu alphabet”, nếu sai in ra “{c}
# không phải là kí tự alphabet.

# %%
c = input()
if c.isalpha():
  print(f"{c} là kí tự alphabet")
else:
  print(f"{c} không phải là kí tự alphabet")
# Out:
# g
# g là kí tự alphabet

# %% [markdown]
# Bài 5: Nhập vào chữ cái hoa A, in ra chữ cái thường liền trước chữ cái a thường tương
# ứng của A. Xét TH khi c = ‘A’ là đặc biệt.

# %%
c = str(input())
if c == 'A':
  print("z")
else:
  c_thuong = c.lower()
  c_lienKe = ord(c_thuong)-1
  print(chr(c_lienKe))
# Out:
# R
# q

# %% [markdown]
# Bài 6. Nhập vào 3 số a, b, c. Kiểm tra xem đây có phải là cạnh của 1 tam giác không,
# nếu đúng thì tính diện tích của tam giác đó, in ra với 1 chữ số phần thập phân, nếu nó
# không phải 3 cạnh của tam giác thì in ra “Khong phai 3 canh cua tam giac”.

# %%
a, b, c = map(float, input().split())
if a**2 + b**2 == c**2 or b**2+c**2 == a**2 or c**2+a**2 == b**2:
  p = (a+b+c)/2
  s = ((p*(p-a)*(p-b)*(p-c)))**0.5
  print(s)
else:
  print("Khong phai 3 canh cua tam giac")
# Out:
# 1 5 6
# Khong phai 3 canh cua tam giac

# %% [markdown]
# Bài 7: Nhập vào một chuỗi gồm các kí tự thường độ dài >=20, in ra chữ cái thứ năm và
# thứ chín của chuỗi này.

# %%
chuoiKiTu = str(input())
if len(chuoiKiTu) >= 20:
  print(chuoiKiTu[4]) #python đếm bắt đầu từ số thứ tự thứ 0 nên phải N = n - 1
  print(chuoiKiTu[8])
# Out:
# NhapHoVaTenCuaChiSoDien
# H
# T

# %% [markdown]
# Bài 8: Nhập vào họ tên chủ hộ và chỉ số điện kế tháng trước và chỉ số điện kế tháng này,
# tính tiền điện tháng này cho hộ biết:
# - Từ 0 – 50kWh: 1.984 đồng/kWh
# - Bậc 2: Từ 51 – 100 kWh: 2.050 đồng/kWh
# - Bậc 3: Từ 101 – 200 kWh: 2.380 đồng/kWh
# - Bậc 4: Từ 201 – 300 kWh: 2.998 đồng/kWh
# - Bậc 5: Từ 301 – 400 kWh: 3.350 đồng/kWh
# - Bậc 6: Từ 401 trở đi kWh: 3.460 đồng/kWh
# Tính thêm tiền VAT 8%. Chỉ lấy đến đơn vị đồng
# Input Ouput
# Ten chu ho: Pham Xuan Toai
# Chi so thang truoc: 1020
# Chi so thang nay: 1070
#
# Ho va ten: Pham Xuan Toai
# Tien phai tra la: 107136
#
# Ten chu ho: Nguyen Xuan Long
# Chi so thang truoc: 2097
# Chi so thang nay: 2278
#
# Ho va ten: Nguyen Xuan Long
# Tien phai tra la: 426038
#
# Ten chu ho: Nguyen Xuan Hai
# Chi so thang truoc: 2000
# Chi so thang nay: 2586
#
# Ho va ten: Nguyen Xuan Hai
# Tien phai tra la: 1855505

# %%
from re import T
HoVaTen = str(input())
ChiSoDienKeTruoc = int(input())
ChiSoDienKeHienTai = int(input())
TongDien = (ChiSoDienKeHienTai - ChiSoDienKeTruoc)
if TongDien <= 50:
  TienDienBac0 = TongDien*1984*1.08
  print(TienDienBac0)
elif 51 <= TongDien <= 100:
  TienDienBac2 = ((TongDien-50)*2050 + 50*1984)*1.08
  print(TienDienBac2)
elif 101 <= TongDien <= 200:
  TienDienBac3 = ((TongDien-100)*2380 + 50*2050 + 50*1984)*1.08
  print(TienDienBac3)
elif 201 <= TongDien <= 300:
  TienDienBac4 = ((TongDien-200)*2998 + 50*2380 + 50*2050 + 50*1984)*1.08
  print(TienDienBac4)
elif 301 <= TongDien <= 400:
  TienDienBac5 = ((TongDien-300)*3350 + 50*2998 + 50*2380 + 50*20)*1.08
elif TongDien >= 401:
  TienDienBac6 = ((TongDien-400)*3460 + 50*3350 + 50*2998 + 50*2380 + 50*2050 + 50*1984)*1.08
  print(TienDienBac6)
# Out:
# Binh
# 2097
# 2278
# 426038.4

# %%
a = list(map(float, input().strip().split()))
def trungBinhCongSoChan(a):
  tong = 0
  dem = 0
  for i in range (0, len(a)):
    if a[i]%2 == 0:
      tong += a[i]
      dem += 1
      trungBinhCong = tong/dem
  if dem == 0:
    return 0

  return trungBinhCong

print(trungBinhCongSoChan(a))
# Out:
# -2 -4 10 6
# 2.5

# %% [markdown]
# Bài 9:Kiểm tra số chẵn lẻ: Viết chương trình nhập một số nguyên, kiểm tra và in ra số đó
# là số chẵn hay số lẻ.

# %%
n = int(input())
if n%2 == 0:
  print("Đây là số chẵn")
elif n%2 != 0:
  print("Đây là số lẻ")
# Out:
# 5
# Đây là số lẻ

# %% [markdown]
# Bài 10:Kiểm tra số có tận cùng 5 không: Viết chương trình nhập một số nguyên, kiểm tra số đó có tận cùng 5 không, nếu đúng in ra “True”, nếu sai in ra “False”.

# %%
n = int(input())
soCuoi = n%10
if soCuoi == 5:
  print("true")
else:
  print("False")
# Out:
# 124590
# False

# %% [markdown]
# Bài 11:Kiểm tra số có chia hết cho 3 và 5 không: Viết chương trình nhập một số nguyên,
# kiểm tra số đó có chia hết cho 3 và 5 không, nếu đúng in ra “True”, nếu sai in ra
# “False”.

# %%
n = int(input())
phepChiaDu = n%15
if phepChiaDu == 0:
  print("True")
else:
  print("False")
# Out:
# 27
# False

# %% [markdown]
# Bài 12:Kiểm tra tuổi đủ điều kiện bầu cử: Viết chương trình nhập năm sinh của một
# người, kiểm tra xem người đó có đủ 18 tuổi để đi bầu cử hay không.

# %%
namSinh = int(input("Nhập năm sinh: "))
if namSinh >= 18:
  print(" đủ tuổi đi bầu cử")
else:
  print("Không đủ tuổi đi bầu cử")
# Out:
# Nhập năm sinh: 27
#  đủ tuổi đi bầu cử

# %% [markdown]
# Bài 13: So sánh 2 số: Viết chương trình nhập vào hai số, in ra số lớn hơn hoặc thông báo
# nếu hai số bằng nhau.

# %%
haiSo = list(map(float, input().split()))
if haiSo[0] > haiSo[1]:
  print(haiSo[0])
elif haiSo[0] < haiSo[1]:
  print(haiSo[1])
else:
  print("Hai số bằng nhau")
# Out:
# 1 4
# 4.0

# %% [markdown]
# Bài 14: Kiểm tra ký tự nhập vào là chữ hay số: Viết chương trình nhập một ký tự, kiểm
# tra xem ký tự đó là chữ cái hay số.

# %%
n = str(input())
if n.isdigit():
  print("Đây là số")
elif n.isalpha():
  print("Đây là chữ cái")
# Out:
# N
# Đây là chữ cái

# %% [markdown]
# Bài 15: Tính điểm học lực
# Nhập điểm (0-10), phân loại học lực theo quy tắc:
# >=8: Giỏi; >=6.5 và <8: Khá; >=5 và <6.5: Trung bình; <5: Yếu

# %%
n = float(input())
if n >= 8:
  print("Giỏi")
elif 6.5 <= n < 8:
  print("Khá")
elif 5 <= n <6.5:
  print("Trung bình")
elif n < 5:
    print("Yếu")
# Out:
# 3
# Yếu

# %% [markdown]
# Bài 16: Kiểm tra năm nhuận: Viết chương trình nhập năm, kiểm tra xem năm đó có phải
# năm nhuận hay không. (Năm nhuận nếu chia hết cho 400 hoặc chia hết cho 4
# nhưng không chia hết cho 100)

# %%
n = int(input())
